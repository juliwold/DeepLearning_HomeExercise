# %%
# other libraries
import os
import glob
import shutil
from pathlib import Path
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import folium
#import warnings
#warnings.filterwarnings("ignore")      
#import sys

# geospatial packages
# from osgeo import gdal, ogr, osr
import geopandas as gpd
from shapely.geometry import Polygon
import rasterio as rio
from ultralytics import YOLO

# %%
path_to_model = "..\\models\\my_annotations\\my_annotations_yolov8m.pt_640\\weights\\best.pt"

train_config = "..\\data\\annotated_data\\train\\my_annotations\\train_config.yaml"
project = "..\\models\\my_annotations\\my_annotations_yolov8m.pt_640"
conf = 0.60

path_to_tiles = "..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun"
buffer_size_m = 1

# %%
path_to_tiles
# Out:
# '..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun'

# %%
model = YOLO(path_to_model)
model

# %%
model.predict(
    source=path_to_tiles,
    project=project,
    conf=conf,
    save=True,
    save_txt=True,
    save_conf=True,
    line_width=1
)
# Out:
# image 1/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_09.tif: 640x640 (no detections), 1672.1ms
# image 2/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_10.tif: 640x640 7 trees, 1269.7ms
# image 3/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_12.tif: 640x640 9 trees, 1073.7ms
# image 4/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_13.tif: 640x640 6 trees, 1550.5ms
# image 5/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_14.tif: 640x640 11 trees, 1894.6ms
# image 6/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_03_15.tif: 640x640 5 trees, 1615.7ms
# image 7/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_08.tif: 640x640 6 trees, 2282.3ms
# image 8/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_09.tif: 640x640 4 trees, 1638.5ms
# image 9/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_10.tif: 640x640 8 trees, 1420.6ms
# image 10/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_11.tif: 640x640 3 trees, 1543.2ms
# image 11/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_12.tif: 640x640 8 trees, 1347.5ms
# image 12/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_13.tif: 640x640 10 trees, 1777.1ms
# image 13/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_14.tif: 640x640 6 trees, 1618.0ms
# image 14/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_15.tif: 640x640 12 trees, 1986.7ms
# image 15/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_04_16.tif: 640x640 4 trees, 2469.8ms
# image 16/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_09.tif: 640x640 6 trees, 1822.6ms
# image 17/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_10.tif: 640x640 9 trees, 2158.7ms
# image 18/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_11.tif: 640x640 7 trees, 1509.2ms
# image 19/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_12.tif: 640x640 6 trees, 1361.7ms
# image 20/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_13.tif: 640x640 3 trees, 1661.5ms
# image 21/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_14.tif: 640x640 3 trees, 1817.4ms
# image 22/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_15.tif: 640x640 1 tree, 3288.8ms
# image 23/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_05_16.tif: 640x640 9 trees, 2016.1ms
# image 24/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_09.tif: 640x640 9 trees, 2009.0ms
# image 25/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_10.tif: 640x640 7 trees, 2438.1ms
# image 26/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_11.tif: 640x640 10 trees, 1981.3ms
# image 27/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_12.tif: 640x640 6 trees, 1562.3ms
# image 28/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_13.tif: 640x640 2 trees, 2137.0ms
# image 29/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_14.tif: 640x640 1 tree, 2199.9ms
# image 30/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_15.tif: 640x640 4 trees, 1492.8ms
# image 31/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_16.tif: 640x640 13 trees, 1345.7ms
# image 32/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_06_17.tif: 640x640 4 trees, 1436.8ms
# image 33/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_07_08.tif: 640x640 8 trees, 1506.3ms
# image 34/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_07_09.tif: 640x640 11 trees, 2958.5ms
# image 35/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun
416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_27.tif: 640x640 (no detections), 1764.6ms
# image 186/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_28.tif: 640x640 (no detections), 1581.6ms
# image 187/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_29.tif: 640x640 5 trees, 1484.7ms
# image 188/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_30.tif: 640x640 2 trees, 1329.3ms
# image 189/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_31.tif: 640x640 5 trees, 1496.3ms
# image 190/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_32.tif: 640x640 5 trees, 1469.9ms
# image 191/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_33.tif: 640x640 10 trees, 1632.3ms
# image 192/416 c:\Users\juliwold\OneDrive - Norwegian University of Life Sciences\Documents\projects\DeepLearning_HomeExercise\scripts\..\data\tiles\test_data\10m_braatan_40m_20230605_sun\braatan_40m_20230605_sun_15_36.tif: 640x640 10 trees, 1588.9ms
# ...
#          [140, 150, 163],
#          ...,
#          [144, 158, 162],
#          [104, 116, 135],
#          [148, 172, 182]],
#
#         [[ 75,  97, 108],
#          [ 94,  95, 106],
#          [146, 148, 159],
#          ...,
#          [123, 142, 154],
#          [105, 129, 141],
#          [138, 156, 169]],
#
#         ...,
#
#         [[157, 149, 156],
#          [157, 153, 157],
#          [173, 174, 179],
#          ...,
#          [ 90, 108, 126],
#          [ 91, 111, 122],
#          [117, 139, 145]],
#
#         [[155, 154, 165],
#          [155, 158, 164],
#          [183, 191, 196],
#          ...,
#          [ 90, 103, 121],
#          [ 90, 105, 119],
#          [115, 131, 142]],
#
#         [[141, 150, 164],
#          [151, 159, 170],
#          [197, 210, 217],
#          ...,
#          [115, 133, 147],
#          [101, 119, 134],
#          [107, 125, 135]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_26_39.tif'
#  probs: None
#  speed: {'preprocess': 8.99505615234375, 'inference': 1505.4559707641602, 'postprocess': 2.969503402709961},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[ 32,  47,  59],
#          [ 54,  79, 102],
#          [117, 135, 159],
#          ...,
#          [146, 179, 198],
#          [158, 189, 207],
#          [155, 186, 197]],
#
#         [[ 48,  68,  85],
#          [ 43,  56,  77],
#          [ 74, 105, 113],
#          ...,
#          [149, 179, 192],
#          [149, 181, 193],
#          [152, 183, 193]],
#
#         [[161, 180, 191],
#          [120, 150, 170],
#          [ 95, 104, 120],
#          ...,
#          [148, 175, 191],
#          [142, 173, 185],
#          [163, 190, 201]],
#
#         ...,
#
#         [[100, 106, 121],
#          [101, 112, 123],
#          [ 90,  94, 115],
#          ...,
#          [ 46,  51,  61],
#          [ 26,  48,  55],
#          [ 63,  86,  86]],
#
#         [[ 94, 106, 120],
#          [113, 124, 137],
#          [127, 138, 152],
#          ...,
#          [ 21,  35,  43],
#          [ 50,  67,  76],
#          [ 97, 120, 121]],
#
#         [[130, 147, 159],
#          [153, 164, 177],
#          [137, 149, 157],
#          ...,
#          [ 68,  89,  96],
#          [ 71,  88,  95],
#          [106, 127, 130]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_26_40.tif'
#  probs: None
#  speed: {'preprocess': 10.004281997680664, 'inference': 1494.4992065429688, 'postprocess': 2.0024776458740234},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[ 82,  82,  74],
#          [ 66,  64,  60],
#          [ 48,  51,  42],
#          ...,
#          [104, 103, 107],
#          [ 87,  91,  90],
#          [ 68,  70,  69]],
#
#         [[116, 118, 109],
#          [ 93,  92,  82],
#          [ 77,  78,  68],
#          ...,
#          [101,  99, 103],
#          [ 81,  83,  84],
#          [ 65,  64,  63]],
#
#         [[ 85,  86,  80],
#          [107, 110,  96],
#          [122, 122, 114],
#          ...,
#          [ 89,  89,  90],
#          [ 71,  72,  71],
#          [ 73,  74,  73]],
#
#         ...,
#
#         [[ 82,  81,  67],
#          [ 93,  86,  71],
#          [107, 104,  88],
#          ...,
#          [ 99,  97, 100],
#          [ 91,  88,  93],
#          [ 84,  82,  87]],
#
#         [[ 91,  92,  73],
#          [118, 117,  95],
#          [149, 143, 126],
#          ...,
#          [102,  97,  97],
#          [ 67,  64,  67],
#          [ 64,  65,  69]],
#
#         [[102, 100,  83],
#          [138, 138, 122],
#          [153, 146, 130],
#          ...,
#          [121, 116, 121],
#          [ 82,  78,  82],
#          [ 67,  67,  66]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_27_35.tif'
#  probs: None
#  speed: {'preprocess': 9.312629699707031, 'inference': 1448.0459690093994, 'postprocess': 2.1147727966308594},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[ 97,  95,  97],
#          [ 88,  91,  89],
#          [ 86,  91,  88],
#          ...,
#          [118, 121, 129],
#          [106, 107, 111],
#          [ 87,  97, 106]],
#
#         [[ 88,  89,  91],
#          [ 85,  88,  90],
#          [ 95,  99,  99],
#          ...,
#          [113, 116, 122],
#          [148, 152, 157],
#          [145, 147, 156]],
#
#         [[ 89,  90,  93],
#          [ 83,  84,  83],
#          [ 99, 102, 103],
#          ...,
#          [ 91,  89,  92],
#          [115, 121, 126],
#          [132, 138, 145]],
#
#         ...,
#
#         [[ 49,  40,  35],
#          [ 37,  27,  27],
#          [ 39,  24,  28],
#          ...,
#          [ 59,  54,  62],
#          [ 80,  82,  87],
#          [ 72,  72,  76]],
#
#         [[ 71,  61,  59],
#          [ 61,  51,  51],
#          [ 61,  49,  50],
#          ...,
#          [ 74,  79,  76],
#          [109, 108, 117],
#          [100,  99, 106]],
#
#         [[ 83,  73,  71],
#          [ 74,  66,  62],
#          [ 65,  56,  51],
#          ...,
#          [ 71,  72,  70],
#          [123, 120, 121],
#          [122, 119, 119]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_27_36.tif'
#  probs: None
#  speed: {'preprocess': 9.743452072143555, 'inference': 1485.1288795471191, 'postprocess': 3.000974655151367},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[ 86,  84,  92],
#          [112, 117, 119],
#          [142, 150, 150],
#          ...,
#          [ 96, 121, 135],
#          [109, 135, 156],
#          [128, 153, 173]],
#
#         [[ 53,  60,  60],
#          [ 83,  79,  90],
#          [ 95, 101, 103],
#          ...,
#          [ 98, 123, 138],
#          [114, 138, 155],
#          [126, 147, 168]],
#
#         [[ 46,  49,  52],
#          [ 88,  91,  99],
#          [128, 131, 139],
#          ...,
#          [131, 154, 166],
#          [ 95, 118, 135],
#          [ 83,  99, 123]],
#
#         ...,
#
#         [[113, 112, 112],
#          [111, 114, 112],
#          [106, 108, 108],
#          ...,
#          [196, 217, 234],
#          [172, 190, 212],
#          [168, 186, 212]],
#
#         [[102, 101, 103],
#          [ 92,  91,  92],
#          [ 79,  81,  78],
#          ...,
#          [206, 227, 243],
#          [191, 214, 232],
#          [185, 212, 231]],
#
#         [[ 83,  89,  85],
#          [ 62,  61,  60],
#          [ 57,  52,  55],
#          ...,
#          [176, 201, 220],
#          [183, 209, 228],
#          [191, 220, 239]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_27_37.tif'
#  probs: None
#  speed: {'preprocess': 8.18634033203125, 'inference': 1509.627103805542, 'postprocess': 1.9581317901611328},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[204, 225, 236],
#          [205, 221, 234],
#          [202, 212, 223],
#          ...,
#          [119, 110, 116],
#          [ 71,  69,  76],
#          [ 90, 100, 107]],
#
#         [[165, 176, 191],
#          [183, 196, 214],
#          [195, 209, 218],
#          ...,
#          [142, 154, 151],
#          [105, 101, 106],
#          [ 68,  73,  80]],
#
#         [[115, 125, 142],
#          [151, 152, 175],
#          [166, 181, 192],
#          ...,
#          [186, 184, 189],
#          [132, 138, 129],
#          [ 85,  88,  99]],
#
#         ...,
#
#         [[124, 167, 174],
#          [122, 163, 174],
#          [117, 159, 158],
#          ...,
#          [125, 146, 153],
#          [144, 150, 157],
#          [178, 192, 200]],
#
#         [[144, 175, 177],
#          [122, 150, 159],
#          [ 81, 119, 120],
#          ...,
#          [138, 152, 157],
#          [124, 135, 139],
#          [153, 163, 169]],
#
#         [[122, 163, 172],
#          [ 99, 134, 148],
#          [ 56,  94, 110],
#          ...,
#          [145, 147, 149],
#          [107, 127, 129],
#          [121, 124, 129]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_27_38.tif'
#  probs: None
#  speed: {'preprocess': 8.004426956176758, 'inference': 1399.162769317627, 'postprocess': 0.9989738464355469},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[ 22,  21,  22],
#          [ 60,  55,  58],
#          [ 59,  48,  50],
#          ...,
#          [131, 128, 130],
#          [115, 118, 113],
#          [ 99,  96,  92]],
#
#         [[ 27,  22,  23],
#          [ 71,  62,  68],
#          [ 80,  68,  68],
#          ...,
#          [109, 110, 106],
#          [ 97,  92,  93],
#          [ 88,  81,  82]],
#
#         [[ 23,  12,  14],
#          [ 42,  29,  35],
#          [ 52,  45,  46],
#          ...,
#          [100,  96,  95],
#          [ 81,  78,  77],
#          [ 77,  73,  73]],
#
#         ...,
#
#         [[ 45,  44,  41],
#          [ 17,  21,  17],
#          [ 29,  25,  21],
#          ...,
#          [162, 182, 205],
#          [174, 188, 212],
#          [168, 185, 202]],
#
#         [[ 28,  27,  25],
#          [ 22,  25,  21],
#          [ 29,  28,  24],
#          ...,
#          [170, 180, 210],
#          [171, 183, 206],
#          [167, 187, 204]],
#
#         [[ 20,  20,  17],
#          [ 16,  15,  16],
#          [ 20,  16,  15],
#          ...,
#          [180, 197, 213],
#          [157, 177, 190],
#          [160, 175, 194]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_28_36.tif'
#  probs: None
#  speed: {'preprocess': 11.004447937011719, 'inference': 1486.4435195922852, 'postprocess': 2.6276111602783203},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[125, 124, 122],
#          [133, 136, 136],
#          [100, 105, 103],
#          ...,
#          [167, 198, 219],
#          [172, 214, 228],
#          [139, 170, 189]],
#
#         [[125, 130, 126],
#          [112, 114, 118],
#          [ 76,  82,  82],
#          ...,
#          [163, 189, 204],
#          [140, 173, 193],
#          [147, 187, 204]],
#
#         [[117, 125, 121],
#          [ 81,  79,  79],
#          [ 52,  51,  50],
#          ...,
#          [134, 157, 170],
#          [129, 156, 182],
#          [129, 167, 189]],
#
#         ...,
#
#         [[121, 117, 126],
#          [ 80,  88,  92],
#          [ 68,  71,  81],
#          ...,
#          [142, 188, 199],
#          [149, 191, 207],
#          [106, 157, 166]],
#
#         [[129, 134, 140],
#          [103, 105, 110],
#          [ 76,  85,  89],
#          ...,
#          [154, 203, 213],
#          [175, 221, 233],
#          [134, 184, 187]],
#
#         [[142, 147, 154],
#          [112, 113, 120],
#          [103, 108, 114],
#          ...,
#          [149, 192, 200],
#          [181, 224, 236],
#          [159, 207, 213]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_28_37.tif'
#  probs: None
#  speed: {'preprocess': 8.18324089050293, 'inference': 1408.543348312378, 'postprocess': 0.99945068359375},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[120, 114, 112],
#          [126, 121, 119],
#          [109, 110, 106],
#          ...,
#          [ 84,  91,  95],
#          [ 71,  77,  84],
#          [ 78,  82,  90]],
#
#         [[107, 109, 105],
#          [119, 123, 119],
#          [113, 107, 110],
#          ...,
#          [ 83,  80,  90],
#          [ 73,  74,  84],
#          [ 91,  93, 104]],
#
#         [[ 94,  91,  92],
#          [110, 107, 112],
#          [115, 115, 113],
#          ...,
#          [ 81,  86,  93],
#          [ 79,  79,  89],
#          [ 96,  99, 110]],
#
#         ...,
#
#         [[ 77,  81,  84],
#          [ 73,  77,  75],
#          [ 62,  64,  64],
#          ...,
#          [118, 136, 142],
#          [157, 166, 171],
#          [ 71,  85,  92]],
#
#         [[ 75,  76,  81],
#          [ 81,  81,  81],
#          [ 75,  74,  71],
#          ...,
#          [146, 160, 164],
#          [112, 127, 134],
#          [ 67,  78,  90]],
#
#         [[ 77,  73,  72],
#          [ 74,  69,  75],
#          [ 73,  72,  80],
#          ...,
#          [116, 125, 130],
#          [ 58,  70,  73],
#          [ 71,  79,  83]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_29_36.tif'
#  probs: None
#  speed: {'preprocess': 8.997917175292969, 'inference': 1483.9608669281006, 'postprocess': 1.0120868682861328},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'tree'}
#  orig_img: array([[[142, 149, 144],
#          [154, 158, 162],
#          [162, 172, 169],
#          ...,
#          [103, 128, 141],
#          [167, 189, 206],
#          [158, 184, 196]],
#
#         [[134, 143, 142],
#          [152, 157, 154],
#          [156, 169, 165],
#          ...,
#          [ 93, 112, 131],
#          [143, 163, 185],
#          [163, 184, 196]],
#
#         [[106, 114, 121],
#          [129, 132, 136],
#          [135, 140, 140],
#          ...,
#          [ 95, 118, 144],
#          [120, 140, 160],
#          [162, 168, 198]],
#
#         ...,
#
#         [[ 79,  98, 105],
#          [ 70,  83,  90],
#          [ 68,  74,  90],
#          ...,
#          [140, 155, 164],
#          [119, 130, 143],
#          [ 90, 110, 122]],
#
#         [[ 56,  71,  84],
#          [ 46,  59,  66],
#          [ 46,  54,  70],
#          ...,
#          [145, 154, 167],
#          [130, 144, 151],
#          [120, 138, 151]],
#
#         [[ 58,  70,  85],
#          [ 36,  49,  60],
#          [ 32,  44,  57],
#          ...,
#          [122, 132, 145],
#          [103, 120, 134],
#          [122, 137, 156]]], dtype=uint8)
#  orig_shape: (1177, 1177)
#  path: 'c:\\Users\\juliwold\\OneDrive - Norwegian University of Life Sciences\\Documents\\projects\\DeepLearning_HomeExercise\\scripts\\..\\data\\tiles\\test_data\\10m_braatan_40m_20230605_sun\\braatan_40m_20230605_sun_30_36.tif'
#  probs: None
#  speed: {'preprocess': 7.004022598266602, 'inference': 1468.1153297424316, 'postprocess': 2.001047134399414}]

# %% [markdown]
# ## Post-processing

# %%
gtiffs = glob.glob(f"{path_to_tiles}\\*.tif")
labels = glob.glob(f"{project}\\predict\\labels\\*.txt")
print(f"There a total of {len(gtiffs)} .tif files")
print(f"There a total of {len(labels)} .label files")
# Out:
# There a total of 416 .tif files
# There a total of 379 .label files

# %%
# load tile index
path_to_tile_index = f"{path_to_tiles}//braatan_40m_20230605_sun_tile_index.shp"
tile_index = gpd.read_file(path_to_tile_index)
tile_index
# Out:
#                                       ID  \
# 0     braatan_40m_20230605_sun_01_01.tif
# 1     braatan_40m_20230605_sun_01_02.tif
# 2     braatan_40m_20230605_sun_01_03.tif
# 3     braatan_40m_20230605_sun_01_04.tif
# 4     braatan_40m_20230605_sun_01_05.tif
# ...                                  ...
# 1491  braatan_40m_20230605_sun_34_40.tif
# 1492  braatan_40m_20230605_sun_34_41.tif
# 1493  braatan_40m_20230605_sun_34_42.tif
# 1494  braatan_40m_20230605_sun_34_43.tif
# 1495  braatan_40m_20230605_sun_34_44.tif
#
#                                                geometry
# 0     POLYGON ((610764.790 6622705.168, 610774.794 6...
# 1     POLYGON ((610773.791 6622705.168, 610783.795 6...
# 2     POLYGON ((610782.792 6622705.168, 610792.796 6...
# 3     POLYGON ((610791.793 6622705.168, 610801.797 6...
# 4     POLYGON ((610800.794 6622705.168, 610810.798 6...
# ...                                                 ...
# 1491  POLYGON ((611115.829 6622408.136, 611125.833 6...
# 1492  POLYGON ((611124.830 6622408.136, 611134.834 6...
# 1493  POLYGON ((611133.831 6622408.136, 611143.835 6...
# 1494  POLYGON ((611142.832 6622408.136, 611152.836 6...
# 1495  POLYGON ((611151.833 6622408.136, 611161.157 6...
#
# [1496 rows x 2 columns]

# %%
from osgeo import gdal, osr
gdal.UseExceptions()

# %%
# Get raster metadata
# pixel resolution (in meters) and tile size in pixels
src_ds = gdal.Open(gtiffs[0]) # get raster datasource
_, xres, _, _, _, yres  = src_ds.GetGeoTransform() # get pixel size in meters
tile_size_m=round(src_ds.RasterXSize*xres)
tile_size_px= round(tile_size_m/abs(xres)) # calculate the tile size in pixels
## Get EPSG code
proj = osr.SpatialReference(wkt=src_ds.GetProjection())
EPSG_code= proj.GetAttrValue('AUTHORITY',1)

print("Resolution: "+str(round(xres,2))+" m")
print("EPSG: "+str(EPSG_code))
# Out:
# Resolution: 0.01 m
# EPSG: 25832

# %%
def yolo2xy(label_file, img_width, img_height):
    """
    Definition: 
Parameters: 
"""
    lfile = open(label_file)
    coords = []
    all_coords = []
    for line in lfile:
        l = line.split(" ")
        label=list(map(float, list(map(float, l[0]))))
        coords = list(map(float, list(map(float, l[1:6]))))
        x1 = float(img_width) * (2.0 * float(coords[0]) - float(coords[2])) / 2.0
        y1 = float(img_height) * (2.0 * float(coords[1]) - float(coords[3])) / 2.0
        x2 = float(img_width) * (2.0 * float(coords[0]) + float(coords[2])) / 2.0
        y2 = float(img_height) * (2.0 * float(coords[1]) + float(coords[3])) / 2.0
        tmp = [int(label[0]), int(x1), int(y1), int(x2), int(y2), float(coords[4])]
        all_coords.append(list(tmp))
    lfile.close()
    return all_coords

# %%
all_bboxes = []
for l in labels:
    label_file_name=Path(l).stem
    gtiff_file = gtiffs[label_file_name in gtiffs]

    r = gdal.Open(gtiff_file)
    tile_size_m = round(r.RasterXSize * xres)
    tile_size_px = round(tile_size_m / abs(xres))
    _, xres, _, _, _, yres  = r.GetGeoTransform() # get pixel size in meters
    proj = osr.SpatialReference(wkt=src_ds.GetProjection())
    EPSG_code = proj.GetAttrValue('AUTHORITY',1)
    img_width = r.RasterXSize
    img_height = r.RasterYSize

    coords = yolo2xy(l, img_width, img_height)

    tile = tile_index[tile_index['ID'] == label_file_name+".tif"]

    ## get tile bounding box geographical coordinates (UTM)
    tile_Xmin, tile_Ymin, tile_Xmax, tile_Ymax = tile.total_bounds

    ## take inner buffer equal to the buffer_size_m (remove overlap)
    tile_inner = tile
    tile_inner.loc[:, "geometry"] = tile_inner.geometry.buffer(-(buffer_size_m / 2))

    ## get inner tile bounding boxes
    inner_Xmin, inner_Ymin, inner_Xmax, inner_Ymax = tile_inner.total_bounds

    # Create box for each observation.
    bboxes = []
    for i in coords:
        X1 = (i[1] * xres) + tile_Xmin
        Y1 = (i[2] * yres) + tile_Ymin + tile_size_m  # Why?
        X2 = (i[3] * xres) + tile_Xmin
        Y2 = (i[4] * yres) + tile_Ymin + tile_size_m  # Why?

        # skip bounding box if its centroid is NOT within the inner tile (removing the overlap)
        X = (X1 + X2) / 2
        Y = (Y1 + Y2 )/2
        if (
            X < inner_Xmin or
            X > inner_Xmax or
            Y < inner_Ymin or
            Y > inner_Ymax):
            #print("continue break")
            continue
        # Create polygon shape from geographical coords
        lat_point_list = [Y1, Y1, Y2, Y2, Y1]
        lon_point_list = [X1, X2, X2, X1, X1]
        polygon_geom = Polygon(zip(lon_point_list, lat_point_list))
        crs = {'init': 'epsg:'+ EPSG_code}
        data= {'class': [i[0]], 'prob': [i[5]]}
        bbox = gpd.GeoDataFrame(data, crs=crs, geometry=[polygon_geom])

        bboxes.append(bbox)
        bboxes_tile = gpd.GeoDataFrame(pd.concat(bboxes, ignore_index=True))
    all_bboxes.append(bboxes_tile)
# Out:
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\NMBU\Miniconda3\envs\deep_learning\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
bounding_boxes = gpd.GeoDataFrame(pd.concat(all_bboxes, ignore_index=True))
bounding_boxes
# Out:
#       class      prob                                           geometry
# 0         0  0.942809  POLYGON ((610853.568 6622684.587, 610855.744 6...
# 1         0  0.817373  POLYGON ((610854.673 6622685.837, 610855.565 6...
# 2         0  0.732856  POLYGON ((610848.706 6622679.318, 610848.978 6...
# 3         0  0.706771  POLYGON ((610848.570 6622678.425, 610848.851 6...
# 4         0  0.666958  POLYGON ((610846.683 6622681.289, 610846.989 6...
# ...     ...       ...                                                ...
# 1827      0  0.644408  POLYGON ((611091.554 6622461.637, 611091.809 6...
# 1828      0  0.619477  POLYGON ((611093.611 6622461.271, 611093.883 6...
# 1829      0  0.923935  POLYGON ((611084.984 6622450.332, 611085.247 6...
# 1830      0  0.783484  POLYGON ((611080.394 6622441.331, 611080.819 6...
# 1831      0  0.625992  POLYGON ((611080.998 6622440.821, 611081.482 6...
#
# [1832 rows x 3 columns]

# %%
# ortho_name = os.path.basename(path_to_predicted)
bounding_boxes.to_file(f"{project}\\predict\\test\\_predictions.shp", driver='ESRI Shapefile') # turn this off if it's not needed
